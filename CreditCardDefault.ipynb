# %%
# Import all necessary libraries. 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Datasets_final/train_dataset_final1.csv')
df.head()
# Out:
#    Customer_ID  marriage  sex  education  LIMIT_BAL   age  pay_0  pay_2  \
# 0         5017         2    0          2      60000  25.0      2      2
# 1         5018         2    1          1     290000  24.0      0      0
# 2         5019         1    0          2     180000  63.0      0      0
# 3         5020         1    1          2     210000  43.0      0      0
# 4         5021         2    0          1     280000  32.0     -2     -2
#
#    pay_3  pay_4  ...  Bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  \
# 0      2      0  ...   20750.63   2000.21      0.00   1134.85   1821.78
# 1     -2     -2  ...    1350.30      0.00      0.17      0.00   2700.10
# 2      0      0  ...   52991.51   2086.94   2199.99   1845.66   2000.35
# 3      0      0  ...   76945.47   3348.07   3380.91   3400.45   2683.97
# 4     -2     -2  ...       1.35    999.78   3186.27  45027.78   2100.09
#
#    pay_amt5  pay_amt6  AVG_Bill_amt  PAY_TO_BILL_ratio  next_month_default
# ...

# %%
df.shape
# Out:
# (25247, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25247 entries, 0 to 25246
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         25247 non-null  int64
#  1   marriage            25247 non-null  int64
#  2   sex                 25247 non-null  int64
#  3   education           25247 non-null  int64
#  4   LIMIT_BAL           25247 non-null  int64
#  5   age                 25121 non-null  float64
#  6   pay_0               25247 non-null  int64
#  7   pay_2               25247 non-null  int64
#  8   pay_3               25247 non-null  int64
#  9   pay_4               25247 non-null  int64
#  10  pay_5               25247 non-null  int64
#  11  pay_6               25247 non-null  int64
#  12  Bill_amt1           25247 non-null  float64
#  13  Bill_amt2           25247 non-null  float64
#  14  Bill_amt3           25247 non-null  float64
# ...

# %%
df.describe()
# Out:
#         Customer_ID      marriage           sex     education       LIMIT_BAL  \
# count  25247.000000  25247.000000  25247.000000  25247.000000    25247.000000
# mean   17640.000000      1.551907      0.604111      1.852101   168342.060443
# std     7288.325459      0.522629      0.489050      0.797379   129892.784807
# min     5017.000000      0.000000      0.000000      0.000000    10000.000000
# 25%    11328.500000      1.000000      0.000000      1.000000    50000.000000
# 50%    17640.000000      2.000000      1.000000      2.000000   140000.000000
# 75%    23951.500000      2.000000      1.000000      2.000000   240000.000000
# max    30263.000000      3.000000      1.000000      6.000000  1000000.000000
#
#                 age         pay_0         pay_2         pay_3         pay_4  \
# count  25121.000000  25247.000000  25247.000000  25247.000000  25247.000000
# mean      35.438199     -0.042857     -0.159544     -0.190359     -0.241415
# ...

# %%
df.columns
# Out:
# Index(['Customer_ID', 'marriage', 'sex', 'education', 'LIMIT_BAL', 'age',
#        'pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6', 'Bill_amt1',
#        'Bill_amt2', 'Bill_amt3', 'Bill_amt4', 'Bill_amt5', 'Bill_amt6',
#        'pay_amt1', 'pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6',
#        'AVG_Bill_amt', 'PAY_TO_BILL_ratio', 'next_month_default'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Customer_ID             0
# marriage                0
# sex                     0
# education               0
# LIMIT_BAL               0
# age                   126
# pay_0                   0
# pay_2                   0
# pay_3                   0
# pay_4                   0
# pay_5                   0
# pay_6                   0
# Bill_amt1               0
# Bill_amt2               0
# Bill_amt3               0
# Bill_amt4               0
# Bill_amt5               0
# Bill_amt6               0
# pay_amt1                0
# pay_amt2                0
# pay_amt3                0
# pay_amt4                0
# pay_amt5                0
# pay_amt6                0
# AVG_Bill_amt            0
# PAY_TO_BILL_ratio       0
# next_month_default      0
# dtype: int64

# %%
df.head()
# Out:
#    Customer_ID  marriage  sex  education  LIMIT_BAL   age  pay_0  pay_2  \
# 0         5017         2    0          2      60000  25.0      2      2
# 1         5018         2    1          1     290000  24.0      0      0
# 2         5019         1    0          2     180000  63.0      0      0
# 3         5020         1    1          2     210000  43.0      0      0
# 4         5021         2    0          1     280000  32.0     -2     -2
#
#    pay_3  pay_4  ...  Bill_amt6  pay_amt1  pay_amt2  pay_amt3  pay_amt4  \
# 0      2      0  ...   20750.63   2000.21      0.00   1134.85   1821.78
# 1     -2     -2  ...    1350.30      0.00      0.17      0.00   2700.10
# 2      0      0  ...   52991.51   2086.94   2199.99   1845.66   2000.35
# 3      0      0  ...   76945.47   3348.07   3380.91   3400.45   2683.97
# 4     -2     -2  ...       1.35    999.78   3186.27  45027.78   2100.09
#
#    pay_amt5  pay_amt6  AVG_Bill_amt  PAY_TO_BILL_ratio  next_month_default
# ...

# %%
#replacing values with labels
#replacing values with there labels
df.replace({'sex': {1 : 'Male', 0 : 'Female'}}, inplace=True)
df.replace({'education' : {1 : 'Graduate School', 2 : 'University', 3 : 'High School', 4 : 'Others'}}, inplace=True)
df.replace({'marriage' : {1 : 'Married', 2 : 'Single', 3 : 'Others'}}, inplace = True)
df.replace({'next_month_default' : {1 : 'Yes', 0 : 'No'}}, inplace = True)

# %%
df['next_month_default'].value_counts()
# Out:
# next_month_default
# No     20440
# Yes     4807
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,5))
sns.countplot(x = 'next_month_default', data = df)
# Out:
# <Axes: xlabel='next_month_default', ylabel='count'>

# %%
#count plot for Sex and with respect to next_month_default
fig, axes = plt.subplots(ncols=2,figsize=(10,5))
sns.countplot(x = 'sex', ax = axes[0], data = df)
sns.countplot(x = 'sex', hue = 'next_month_default',ax = axes[1], data = df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
fil = (df['education'] == 0) | (df['education'] == 5) | (df['education'] == 6) | (df['education'] == 4)
df.loc[fil, 'education'] = 'Others'

# %%
#Value counts for education category
df['education'].value_counts()
# Out:
# education
# University         11717
# Graduate School     8988
# High School         4115
# Others               427
# Name: count, dtype: int64

# %%
#count plot for education and with respect to next_month_default
fig, axes = plt.subplots(ncols=2,figsize=(18,5))
sns.countplot(x = 'education', ax = axes[0], data = df)
sns.countplot(x = 'education', hue = 'next_month_default',ax = axes[1], data = df)
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
#Value counts for marriage category
fil = df['marriage']==0
df.loc[fil,'marriage'] = 'Others'
df['marriage'].value_counts()
# Out:
# marriage
# Single     2702
# Married    2262
# Others       52
# Name: count, dtype: int64

# %%
#count plot for marriage and with respect to next_month_default
fig, axes = plt.subplots(ncols=2,figsize=(10,5))
sns.countplot(x = 'marriage', ax = axes[0], data = df)
sns.countplot(x = 'marriage', hue = 'next_month_default',ax = axes[1], data = df)
# Out:
# <Axes: xlabel='marriage', ylabel='count'>

# %%
#values count for age 
plt.figure(figsize=(20,8))
sns.countplot(x = 'age', data = df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Group and count values
age_default_counts = df.groupby(['age', 'next_month_default']).size().unstack(fill_value=0)

# Plot stacked bar chart
age_default_counts.plot(kind='bar', stacked=True, figsize=(20,8), colormap='coolwarm')

plt.title('Default Count by Age (Stacked Bar)')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.legend(title='Defaulted Next Month')
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 18))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

pay_cols = ['pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6']

df_melted = df.melt(id_vars='next_month_default', value_vars=pay_cols,
                    var_name='Month', value_name='Payment_Status')

plt.figure(figsize=(14, 6))
sns.boxplot(x='Month', y='Payment_Status', hue='next_month_default', data=df_melted)
plt.title("Payment Delay by Month and Defaulter Status")
plt.ylabel("Payment Status (-2: No Bill, 0: On Time, >0: Delay in Months)")
plt.xlabel("Month")
plt.legend(title='Is Defaulter', labels=['No', 'Yes'])
plt.show()

# %%
grouped = df.groupby('next_month_default')[pay_cols].mean()

plt.figure(figsize=(10, 4))
sns.heatmap(grouped, annot=True, cmap='coolwarm', center=0)
plt.title("Average Payment Delay by Default Status")
plt.ylabel("Defaulted Next Month")
plt.xlabel("Month")
plt.show()

# %%
pay_means = df.groupby('next_month_default')[pay_cols].mean().T
pay_means.columns = ['Not Defaulter', 'Defaulter']

pay_means.plot(marker='o', figsize=(10, 5))
plt.title("Trend of Payment Delay Over Months")
plt.ylabel("Average Payment Delay")
plt.xlabel("Month")
plt.grid(True)
plt.show()

# %%
repay_cols = ['pay_amt1', 'pay_amt2', 'pay_amt3',
              'pay_amt4', 'pay_amt5', 'pay_amt6']

# Compute mean and std temporarily
repay_mean = df[repay_cols].mean(axis=1)
repay_std = df[repay_cols].std(axis=1)

# Compute coefficient of variation directly
df['repay_cv'] = repay_std / (repay_mean + 1e-5)  # small constant to avoid division by zero

# %%
df.columns
# Out:
# Index(['Customer_ID', 'marriage', 'sex', 'education', 'LIMIT_BAL', 'age',
#        'pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6', 'Bill_amt1',
#        'Bill_amt2', 'Bill_amt3', 'Bill_amt4', 'Bill_amt5', 'Bill_amt6',
#        'pay_amt1', 'pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6',
#        'AVG_Bill_amt', 'PAY_TO_BILL_ratio', 'repay_cv'],
#       dtype='object')

# %%
sns.boxplot(x='next_month_default', y='repay_cv', data=df)
plt.title("Repayment Consistency (CV) by Defaulter Status")
plt.ylabel("Coefficient of Variation (Higher = More Inconsistent)")
plt.xlabel("Is Defaulter")
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
sns.kdeplot(data=df, x='repay_cv', hue='next_month_default', fill=True)
plt.title("Distribution of Repayment Consistency (CV)")
plt.xlabel("Repayment Coefficient of Variation")
plt.show()

# %%
monthly_repay = df.groupby('next_month_default')[repay_cols].mean().T
monthly_repay.columns = ['Not Defaulter', 'Defaulter']

monthly_repay.plot(marker='o', figsize=(10, 5))
plt.title("Average Monthly Repayment by Defaulter Status")
plt.ylabel("Average Repayment Amount")
plt.xlabel("Month")
plt.grid(True)
plt.show()

# %%
bill_cols = ['Bill_amt1', 'Bill_amt2', 'Bill_amt3',
             'Bill_amt4', 'Bill_amt5', 'Bill_amt6']


df['credit_util_ratio'] = df['AVG_Bill_amt'] / (df['LIMIT_BAL'] + 1e-5)

# %%
def longest_delinquency_streak(row):
    streak, max_streak = 0, 0
    for val in row:
        if val >= 1:
            streak += 1
            max_streak = max(max_streak, streak)
        else:
            streak = 0
    return max_streak

df['delinquency_streak'] = df[pay_cols].apply(longest_delinquency_streak, axis=1)

# %%
df.head()
# Out:
#    Customer_ID marriage     sex        education  LIMIT_BAL  age  pay_0  \
# 0            1  Married    Male       University     220000   32      0
# 1            2   Single  Female  Graduate School     350000   35     -1
# 2            3   Single    Male  Graduate School     310000   39      0
# 3            4  Married  Female       University      20000   47      0
# 4            5   Single    Male       University     500000   30      0
#
#    pay_2  pay_3  pay_4  ...  pay_amt2  pay_amt3  pay_amt4  pay_amt5  pay_amt6  \
# 0      0      0      0  ...   3999.90   1419.80   1999.97   3000.21  30788.71
# 1     -1     -1      0  ...  16267.19   4026.80    234.10   1565.11  26346.39
# 2      0      0      0  ...  10499.83  14000.32  10000.12  10000.16  10000.21
# 3      0      0      2  ...   2799.83      0.14   1499.93      0.02   1000.26
# 4      0      0      0  ...  43095.31   7521.96   9065.17   8841.07  12000.21
#
# ...

# %%
df['repay_to_bill_ratio_avg'] = (
    (df[repay_cols].sum(axis=1)) /
    (df[bill_cols].sum(axis=1) + 1e-5)
)

# %%
from scipy.stats import linregress
import numpy as np

def compute_trend(row):
    x = np.arange(len(row))
    slope, *_ = linregress(x, row)
    return slope

df['repayment_trend'] = df[repay_cols].apply(compute_trend, axis=1)

# %%
df['bill_trend'] = df[bill_cols].apply(compute_trend, axis=1)

# %%
df['max_delay'] = df[pay_cols].replace([-2, -1], 0).max(axis=1)

# %%
df.columns
# Out:
# Index(['Customer_ID', 'marriage', 'sex', 'education', 'LIMIT_BAL', 'age',
#        'pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6', 'Bill_amt1',
#        'Bill_amt2', 'Bill_amt3', 'Bill_amt4', 'Bill_amt5', 'Bill_amt6',
#        'pay_amt1', 'pay_amt2', 'pay_amt3', 'pay_amt4', 'pay_amt5', 'pay_amt6',
#        'AVG_Bill_amt', 'PAY_TO_BILL_ratio', 'repay_cv', 'credit_util_ratio',
#        'delinquency_streak', 'repay_to_bill_ratio_avg', 'repayment_trend',
#        'bill_trend', 'max_delay'],
#       dtype='object')

# %%
drop_cols = [
    'Customer_ID',
    'pay_0', 'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6',
    'Bill_amt1', 'Bill_amt2', 'Bill_amt3',
             'Bill_amt4', 'Bill_amt5', 'Bill_amt6',
    'pay_amt1', 'pay_amt2', 'pay_amt3',
              'pay_amt4', 'pay_amt5', 'pay_amt6',
    'AVG_Bill_amt',
    'PAY_TO_BILL_ratio',
]

df = df.drop(columns=drop_cols)

# %%
df.shape
# Out:
# (25247, 13)

# %%
df.columns
# Out:
# Index(['marriage', 'sex', 'education', 'LIMIT_BAL', 'age',
#        'next_month_default', 'repay_cv', 'credit_util_ratio',
#        'delinquency_streak', 'repay_to_bill_ratio_avg', 'repayment_trend',
#        'bill_trend', 'max_delay'],
#       dtype='object')

# %%
df.head()
# Out:
#   marriage     sex        education  LIMIT_BAL   age next_month_default  \
# 0   Single  Female       University      60000  25.0                 No
# 1   Single    Male  Graduate School     290000  24.0                 No
# 2  Married  Female       University     180000  63.0                 No
# 3  Married    Male       University     210000  43.0                 No
# 4   Single  Female  Graduate School     280000  32.0                 No
#
#    repay_cv  credit_util_ratio  delinquency_streak  repay_to_bill_ratio_avg  \
# 0  0.539108           0.691858                   3                 0.031947
# 1  1.673298           0.008740                   0                 0.266263
# 2  0.061676           0.280122                   0                 0.039850
# 3  0.109803           0.410617                   0                 0.035660
# 4  2.094395           0.042194                   0                 0.723902
#
#    repayment_trend   bill_trend  max_delay
# ...

# %%
#Label encoding 
encode_num = {"sex":{"Female":0,"Male":1}, "next_month_default":{"Yes":1,"No":0}}
df=df.replace(encode_num)

# %%
#creating dummy variables
df = pd.get_dummies(df, columns=['education','marriage'])

# %%
df.drop(['education_Others', 'marriage_Others'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20, 18))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
import seaborn as sns
sns.histplot(df['age'].dropna(), kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['age'].fillna(df['age'].median(), inplace=True)

# %%
df
# Out:
#        sex  LIMIT_BAL   age  next_month_default  repay_cv  credit_util_ratio  \
# 0        0      60000  25.0                   0  0.539108           0.691858
# 1        1     290000  24.0                   0  1.673298           0.008740
# 2        0     180000  63.0                   0  0.061676           0.280122
# 3        1     210000  43.0                   0  0.109803           0.410617
# 4        0     280000  32.0                   0  2.094395           0.042194
# ...    ...        ...   ...                 ...       ...                ...
# 25242    1      90000  33.0                   0  0.429344           0.914583
# 25243    0      60000  49.0                   1  1.320260           0.689528
# 25244    0     120000  31.0                   1  0.927669           0.025599
# 25245    1     390000  40.0                   0  0.139916           0.505843
# 25246    1     160000  58.0                   0  0.000143           0.009019
#
# ...

# %%
df
# Out:
#        sex  LIMIT_BAL   age  next_month_default  repay_cv  credit_util_ratio  \
# 0        0      60000  25.0                   0  0.539108           0.691858
# 1        1     290000  24.0                   0  1.673298           0.008740
# 2        0     180000  63.0                   0  0.061676           0.280122
# 3        1     210000  43.0                   0  0.109803           0.410617
# 4        0     280000  32.0                   0  2.094395           0.042194
# ...    ...        ...   ...                 ...       ...                ...
# 25242    1      90000  33.0                   0  0.429344           0.914583
# 25243    0      60000  49.0                   1  1.320260           0.689528
# 25244    0     120000  31.0                   1  0.927669           0.025599
# 25245    1     390000  40.0                   0  0.139916           0.505843
# 25246    1     160000  58.0                   0  0.000143           0.009019
#
# ...

# %%
X = df.drop(columns=['next_month_default']).values
y = df['next_month_default'].values

# %%
from imblearn.over_sampling import SMOTE

# Separate features and target
X = df.drop(columns=['next_month_default'])
y = df['next_month_default']

# Initialize SMOTE with 50% sampling strategy
smote = SMOTE(sampling_strategy=0.5, random_state=42)

# Apply SMOTE
X_resampled, y_resampled = smote.fit_resample(X, y)

# Display dataset sizes
print(f"Original dataset size: {len(df)} samples")
print(f"Resampled dataset size: {len(y_resampled)} samples")
# Out:
# Original dataset size: 25247 samples
# Resampled dataset size: 30660 samples

# %%
#creating new dataframe from balanced dataset after SMOTE
balanced_df = pd.DataFrame(X_resampled, columns=list(i for i in list(df.describe(include='all').columns) if i != 'next_month_default'))

# %%
#adding target variable to new created dataframe
balanced_df['next_month_default'] = y_resampled

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 5))
sns.countplot(x='next_month_default', data=balanced_df, palette="Set1")
plt.title("Class Distribution After Balancing")
plt.xlabel("next_month_default")
plt.ylabel("Count")
plt.show()

# %%
balanced_df.shape
# Out:
# (30660, 16)

# %%
#seperating dependant and independant variabales
X = balanced_df[(list(i for i in list(balanced_df.describe(include='all').columns) if i != 'next_month_default'))]
Y = balanced_df['next_month_default']

# %%
#importing libraries for data transformation

# %%
X
# Out:
#        sex  LIMIT_BAL        age  repay_cv  credit_util_ratio  \
# 0        0      60000  25.000000  0.539108           0.691858
# 1        1     290000  24.000000  1.673298           0.008740
# 2        0     180000  63.000000  0.061676           0.280122
# 3        1     210000  43.000000  0.109803           0.410617
# 4        0     280000  32.000000  2.094395           0.042194
# ...    ...        ...        ...       ...                ...
# 28611    0      50000  35.000000  0.825163           0.817604
# 28612    1      60000  45.467124  0.348996           0.500996
# 28613    0      50000  38.254279  0.751402           0.712315
# 28614    0      50000  30.306373  0.655552           0.153314
# 28615    1     160000  38.757547  1.258707           0.000960
#
#        delinquency_streak  repay_to_bill_ratio_avg  repayment_trend  \
# 0                       3                 0.031947        76.776286
# 1                       0                 0.266263       269.948286
# ...

# %%
from sklearn.model_selection import train_test_split


# Split into train and validation (80% train, 20% validation)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
X_train, X_val, y_train, y_val = train_test_split(
    X, Y, test_size=0.2, random_state=42, stratify=Y
)

print(f"Training set size: {X_train.shape[0]}")
print(f"Validation set size: {X_val.shape[0]}")

# %%
#importing logistic regression and evaluation metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc

#fitting data into Logistic Regression
logi = LogisticRegression(fit_intercept=True, max_iter=10000)
logi.fit(X_train, y_train)

y_pred_logi = logi.predict(X_val)
y_train_pred_logi=logi.predict(X_train)

evaluate(y_train, y_train_pred_logi, y_val, y_pred_logi)
# Out:
# === Evaluation for Model ===
# Train Accuracy       : 0.82
# Validation Accuracy  : 0.824
# Precision            : 0.857
# Recall               : 0.567
# F1 Score             : 0.682
# F2 Score             : 0.608
# ROC AUC Score        : 0.76

# %%
#class prediction of y

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, fbeta_score

def evaluate(y_train_true, y_train_pred, y_val_true, y_val_pred, model_name="Model"):
    train_acc = round(accuracy_score(y_train_true, y_train_pred), 3)
    val_acc = round(accuracy_score(y_val_true, y_val_pred), 3)
    precision = round(precision_score(y_val_true, y_val_pred), 3)
    recall = round(recall_score(y_val_true, y_val_pred), 3)
    f1 = round(f1_score(y_val_true, y_val_pred), 3)
    f2 = round(fbeta_score(y_val_true, y_val_pred, beta=2), 3)
    roc = round(roc_auc_score(y_val_true, y_val_pred), 3)

    print(f"=== Evaluation for {model_name} ===")
    print("Train Accuracy       :", train_acc)
    print("Validation Accuracy  :", val_acc)
    print("Precision            :", precision)
    print("Recall               :", recall)
    print("F1 Score             :", f1)
    print("F2 Score             :", f2)
    print("ROC AUC Score        :", roc)

# %%
#importing Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

#fitting data into Decision Tree Classifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
# Correct predictions
y_train_pred_dtc = dtc.predict(X_train)
y_val_pred_dtc = dtc.predict(X_val)

# Correct evaluation call
evaluate(y_train, y_train_pred_dtc, y_val, y_val_pred_dtc, model_name="Decision Tree")
# Out:
# === Evaluation for Decision Tree ===
# Train Accuracy       : 1.0
# Validation Accuracy  : 0.765
# Precision            : 0.64
# Recall               : 0.67
# F1 Score             : 0.655
# F2 Score             : 0.664
# ROC AUC Score        : 0.741

# %%
#importing Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)

y_pred_rfc=rfc.predict(X_val)
y_train_pred_rfc=rfc.predict(X_train)

evaluate(y_train, y_train_pred_rfc, y_val, y_pred_rfc, model_name="Random Forest Classifier")
# Out:
# === Evaluation for Random Forest Classifier ===
# Train Accuracy       : 1.0
# Validation Accuracy  : 0.845
# Precision            : 0.833
# Recall               : 0.669
# F1 Score             : 0.742
# F2 Score             : 0.696
# ROC AUC Score        : 0.801

# %%
from sklearn.neural_network import MLPClassifier

# Define the MLP model
mlp = MLPClassifier(hidden_layer_sizes=(64, 32),  # two hidden layers
                    activation='relu',
                    solver='adam',
                    max_iter=200,
                    random_state=42)

# Train the model
mlp.fit(X_train, y_train)

# Predict
y_train_pred = mlp.predict(X_train)
y_val_pred = mlp.predict(X_val)

# Evaluate
evaluate(y_train, y_train_pred, y_val, y_val_pred, model_name="MLP (sklearn)")
# Out:
# === Evaluation for MLP (sklearn) ===
# Train Accuracy       : 0.854
# Validation Accuracy  : 0.814
# Precision            : 0.774
# Recall               : 0.627
# F1 Score             : 0.692
# F2 Score             : 0.651
# ROC AUC Score        : 0.767

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer, fbeta_score

# Define F2 scorer
f2_scorer = make_scorer(fbeta_score, beta=2)

# Parameter grid
param_dist = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [3, 5, 7, 10, 15, 30],
    'learning_rate': [0.01, 0.05, 0.1, 0.3],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'gamma': [0, 0.1, 0.3, 1],
    'reg_alpha': [0, 0.01, 0.1, 1],
    'reg_lambda': [1, 1.5, 2],
}

# Create classifier
xgb_clf = XGBClassifier(
    objective='binary:logistic',
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)

# Randomized search with F2 score
random_search = RandomizedSearchCV(
    estimator=xgb_clf,
    param_distributions=param_dist,
    n_iter=25,
    scoring=f2_scorer,
    cv=3,
    verbose=1,
    n_jobs=-1
)

# Fit the model
random_search.fit(X_train, y_train)

# Best model and parameters
print("Best Parameters:", random_search.best_params_)
best_model = random_search.best_estimator_

# Evaluate
y_train_pred = best_model.predict(X_train)
y_val_pred = best_model.predict(X_val)

evaluate(y_train, y_train_pred, y_val, y_val_pred, model_name="XGBoost (Max F2)")
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# /home/sneax/Downloads/SIDD/SIDD_Small_sRGB_Only/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [21:46:10] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/sneax/Downloads/SIDD/SIDD_Small_sRGB_Only/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [21:46:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/sneax/Downloads/SIDD/SIDD_Small_sRGB_Only/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [21:46:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
import matplotlib.pyplot as plt

# Get importance scores
importances = best_model.feature_importances_

# Try to get column names (optional fallback)
try:
    feature_names = X_train.columns
except:
    feature_names = [f'f{i}' for i in range(len(importances))]

# Sort by importance
sorted_indices = importances.argsort()[::-1]
sorted_names = [feature_names[i] for i in sorted_indices]
sorted_scores = importances[sorted_indices]

# Plot
plt.figure(figsize=(10, 6))
plt.barh(sorted_names[::-1], sorted_scores[::-1])
plt.title("Feature Importance (XGBClassifier)")
plt.xlabel("Importance")
plt.tight_layout()
plt.show()

# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

# === Prepare LightGBM datasets ===
train_data = lgb.Dataset(X_train, label=y_train)
val_data = lgb.Dataset(X_val, label=y_val, reference=train_data)

# === Define parameters ===
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'verbosity': -1,
    'boosting_type': 'gbdt',
    'learning_rate': 0.03,
    'num_leaves': 31,
    'random_state': 42
}

# === Train the model ===
model = lgb.train(
    params,
    train_data,
    valid_sets=[train_data, val_data],
    num_boost_round=500,
)

# === Predictions ===
y_train_pred_prob = model.predict(X_train)
y_val_pred_prob = model.predict(X_val)

# Convert probabilities to binary predictions
y_train_pred = (y_train_pred_prob > 0.5).astype(int)
y_val_pred = (y_val_pred_prob > 0.5).astype(int)

# === Evaluate ===
evaluate(
    y_train_true=y_train,
    y_train_pred=y_train_pred,
    y_val_true=y_val,
    y_val_pred=y_val_pred,
    model_name="LightGBM"
)
# Out:
# === Evaluation for LightGBM ===
# Train Accuracy       : 0.875
# Validation Accuracy  : 0.842
# Precision            : 0.855
# Recall               : 0.635
# F1 Score             : 0.728
# F2 Score             : 0.669
# ROC AUC Score        : 0.79

# %%
type(best_model)
# Out:
# xgboost.sklearn.XGBClassifier

# %%
X_train
# Out:
# array([[ 1.00672516, -0.82527932,  0.73551638, ...,  0.86680419,
#          0.8929267 , -1.25833922],
#        [ 1.00672516,  2.59642222,  0.27911192, ...,  0.86680419,
#         -1.11991275,  0.79469827],
#        [-0.99331977, -0.18868369,  3.93034763, ..., -1.15366309,
#          0.8929267 , -1.25833922],
#        ...,
#        [-0.99331977, -0.82527932, -0.86189924, ..., -1.15366309,
#         -1.11991275,  0.79469827],
#        [ 1.00672516, -0.5069815 , -1.20420258, ...,  0.86680419,
#         -1.11991275,  0.79469827],
#        [-0.99331977, -0.26825814,  0.94575619, ...,  0.86680419,
#          0.8929267 , -1.25833922]], shape=(32704, 15))

# %%
df = pd.read_csv('Datasets_final/validate_dataset_final.csv')

# %%
y_val_test = best_model.predict(X)

# %%
y_val_test = pd.DataFrame(y_val_test, columns=['next_month_default'])

# %%
y_val_test.insert(0, 'Customer_ID', range(1, len(df) + 1))

# %%
y_test = y_val_test

# %%
y_test.to_csv('final.csv', index=False)

# %%
y_test['next_month_default'].value_counts()
# Out:
# next_month_default
# 0    3132
# 1    1884
# Name: count, dtype: int64

# %%
uhh = pd.read_csv('Datasets_final/compare.csv')
okk = pd.read_csv('Datasets_final/train_dataset_final1.csv')

# %%
uhh.shape
# Out:
# (30001, 25)
